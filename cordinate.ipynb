# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open('df.pkl', 'rb') as file:
       df= pickle.load(file)

# %%
df.head()
# Out:
#    price_per_sqft  area  bedrooms   floor_number            area_type  \
# 0         16243.0   985       2.0   middle_floor        Not Specified
# 1         20588.0   850       2.0    lower_floor  Super Built-up Area
# 2         40728.0   933       2.0  Not Specified        Not Specified
# 3         34950.0  2000       6.0  Not Specified        Not Specified
# 4         27777.0  1015       2.0  Not Specified        Not Specified
#
#      property_age  bathroom            property_type    locality
# 0     not_specify         2           Apartment/Flat      Kurla
# 1  moderately_new         2           Apartment/Flat  Sadan wadi
# 2     not_specify         2           Apartment/Flat    Chembur
# 3     not_specify         7  independent_house/villa     Chembur
# 4     not_specify         2           Apartment/Flat      Mulund

# %%
cor=pd.read_csv('location_with_coordinates.csv',usecols=['locality','latitude','longitude'])

# %%
cor=cor.dropna()

# %%
coordinate['locality'].unique().shape
# Out:
# (323,)

# %%
df['locality'].unique().shape
# Out:
# (323,)

# %%
# Out:
#         price_per_sqft  area  bedrooms  floor_number      area_type  \
# 0              16243.0   985       2.0  middle_floor  Not Specified
# 1              16243.0   985       2.0  middle_floor  Not Specified
# 2              16243.0   985       2.0  middle_floor  Not Specified
# 3              16243.0   985       2.0  middle_floor  Not Specified
# 4              16243.0   985       2.0  middle_floor  Not Specified
# ...                ...   ...       ...           ...            ...
# 191288         40000.0   500       1.0  higher_floor    Carpet Area
# 191289         40000.0   500       1.0  higher_floor    Carpet Area
# 191290         40000.0   500       1.0  higher_floor    Carpet Area
# 191291         40000.0   500       1.0  higher_floor    Carpet Area
# 191292         40000.0   500       1.0  higher_floor    Carpet Area
#
#         property_age  bathroom   property_type locality   latitude  longitude
# ...
